# %% [markdown]
# # Pandas Data Analysis Exercise

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Importing files into a dataframe in pandas is very easy
# - It can take the following file types:
#     - Excel
#     - CSV (Comma Separated Values) or txt
#     - SAS
#     - JSON
#     - XML
#     - SQL Data Pull
#     - And many more
# - To use a file with Jupyter Notebooks:
#     - If the file in the same location, you don't need to specify the path
#     - If it's in a different directory, you need specify the path

# %% [markdown]
# > Windows path: `r'C:\User\Documents\'`

# %%
#importing csv
df = pd.read_csv('/Users/bassel_instructor/Documents/Datasets/school_grades.csv')
df
# Out:
#      gender class group parental level of education         lunch  \
# 0      male     group A                 high school      standard
# 1    female     group D            some high school  free/reduced
# 2      male     group E                some college  free/reduced
# 3      male     group B                 high school      standard
# 4      male     group E          associate's degree      standard
# ..      ...         ...                         ...           ...
# 995    male     group C                 high school      standard
# 996    male     group D          associate's degree  free/reduced
# 997  female     group C            some high school  free/reduced
# 998  female     group C                some college      standard
# 999    male     group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 0                 completed          67             67             63
# ...

# %% [markdown]
# - We have 1000 rows and 8 columns
# - We have 3 numeric columns and 5 categorical columns

# %%
# top 10 rows of the data
df.head(10) #by default it uses 5
# Out:
#    gender class group parental level of education         lunch  \
# 0    male     group A                 high school      standard
# 1  female     group D            some high school  free/reduced
# 2    male     group E                some college  free/reduced
# 3    male     group B                 high school      standard
# 4    male     group E          associate's degree      standard
# 5  female     group D                 high school      standard
# 6  female     group A           bachelor's degree      standard
# 7    male     group E                some college      standard
# 8    male     group D                 high school      standard
# 9    male     group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
# get the bottom 7 rows
df.tail(7)
# Out:
#      gender class group parental level of education         lunch  \
# 993  female     group A          associate's degree      standard
# 994    male     group E                 high school  free/reduced
# 995    male     group C                 high school      standard
# 996    male     group D          associate's degree  free/reduced
# 997  female     group C            some high school  free/reduced
# 998  female     group C                some college      standard
# 999    male     group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 993                    none          58             54             58
# 994               completed          86             82             75
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# ...

# %%
#random selection fo a sample
df.sample(12)
# Out:
#      gender class group parental level of education         lunch  \
# 656  female     group D            some high school      standard
# 692  female     group E                 high school      standard
# 432  female     group C          associate's degree  free/reduced
# 38   female     group B                some college  free/reduced
# 584    male     group C           bachelor's degree      standard
# 10     male     group E                some college      standard
# 342    male     group C          associate's degree  free/reduced
# 662  female     group C          associate's degree      standard
# 323    male     group D          associate's degree      standard
# 678  female     group C                some college      standard
# 557    male     group C                some college  free/reduced
# 624  female     group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
print('Num of rows', df.shape[0])
# Out:
# Num of rows 1000

# %%
# check for null values
df.isna().sum()
# Out:
# gender                         0
# class group                    0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# We don't have missing values in teh dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   class group                  1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   class group                  1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 342.5 KB

# %% [markdown]
# - int64 might be an overkill for a score between 0 and 100
# - We can change the data type to be int32 to save on memory

# %%
df['math score'] = df['math score'].astype('int32')

# %%
#get the column list
df.columns
# Out:
# Index(['gender', 'class group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# to automate this
num_col_list = ['math score', 'reading score',
                                'writing score']

for col in num_col_list:
    df[col] = df[col].astype('int32')

# %% [markdown]
# Here are the different subtypes you can use:
#
# - int8 / uint8 : consumes 1 byte of memory, range between -128/127 or 0/255
# - bool : consumes 1 byte, true or false
# - float16 / int16 / uint16: consumes 2 bytes of memory, range between -32768 and 32767 or 0/65535
# - float32 / int32 / uint32 : consumes 4 bytes of memory, range between -2147483648 and 2147483647
# - float64 / int64 / uint64: consumes 8 bytes of memory

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   class group                  1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int32
#  6   reading score                1000 non-null   int32
#  7   writing score                1000 non-null   int32
# dtypes: int32(3), object(5)
# memory usage: 330.8 KB

# %%
df['math score'] = pd.to_numeric(df['math score'], downcast='integer') #use 'float' for decimals
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   class group                  1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int8
#  6   reading score                1000 non-null   int32
#  7   writing score                1000 non-null   int32
# dtypes: int32(2), int8(1), object(5)
# memory usage: 327.8 KB

# %% [markdown]
# ## Data Selection and Filtering

# %%
# build a subet of the data from 100 to 200
df_sub = df.loc[100:200]
df_sub
# Out:
#      gender class group parental level of education         lunch  \
# 100    male     group C                some college  free/reduced
# 101    male     group C                some college      standard
# 102    male     group E                 high school      standard
# 103    male     group D                 high school      standard
# 104  female     group B                some college      standard
# ..      ...         ...                         ...           ...
# 196    male     group D           bachelor's degree      standard
# 197    male     group A             master's degree  free/reduced
# 198  female     group B          associate's degree      standard
# 199    male     group D                 high school      standard
# 200  female     group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 100               completed          54             61             62
# ...

# %% [markdown]
# Using `iloc[]` Get all rows with parental level of education and lunch columns

# %%
df.iloc[:,2:4]
# Out:
#     parental level of education         lunch
# 0                   high school      standard
# 1              some high school  free/reduced
# 2                  some college  free/reduced
# 3                   high school      standard
# 4            associate's degree      standard
# ..                          ...           ...
# 995                 high school      standard
# 996          associate's degree  free/reduced
# 997            some high school  free/reduced
# 998                some college      standard
# 999                some college      standard
#
# [1000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['gender', 'class group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# Specify the columns in the data selection

# %%
df[['parental level of education', 'math score', 'reading score']].head(10)
# Out:
#   parental level of education  math score  reading score
# 0                 high school          67             67
# 1            some high school          40             59
# 2                some college          59             60
# 3                 high school          77             78
# 4          associate's degree          78             73
# 5                 high school          63             77
# 6           bachelor's degree          62             59
# 7                some college          93             88
# 8                 high school          63             56
# 9                some college          47             42

# %%
df['lunch'].head()
# Out:
# 0        standard
# 1    free/reduced
# 2    free/reduced
# 3        standard
# 4        standard
# Name: lunch, dtype: object

# %% [markdown]
# Remove spaces from the column names

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['gender', 'class_group', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# ## Statistical Functions

# %%
df['math_score'].mean()
# Out:
# 66.396

# %%
print(f"Average Score: {df['math_score'].mean()}")
print(f"Highest Score: {df['math_score'].max()}")
print(f"Lowest Score: {df['math_score'].min()}")
print(f"Total Scores: {df['math_score'].sum()}")
# Out:
# Average Score: 66.396
# Highest Score: 100
# Lowest Score: 13
# Total Scores: 66396

# %%
df[['math_score', 'reading_score']].mean()
# Out:
# math_score       66.396
# reading_score    69.002
# dtype: float64

# %% [markdown]
# Similar to SQL:
# ```SQL
# SELECT AVG(math_score), AVG(reading_score)
# FROM df
# ```

# %%
df.describe()
# Out:
#         math_score  reading_score  writing_score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# **Exercise** Build a new column that gives the overall average of all 3 scores

# %%
# select numeric columns only
df_num_cols = df.select_dtypes(include=['int32', 'int8']).columns
df_num_cols
# Out:
# Index(['math_score', 'reading_score', 'writing_score'], dtype='object')

# %%
## select numeric columns only
# method 2
df_num_cols = df.select_dtypes(exclude=['object']).columns
df_num_cols
# Out:
# Index(['math_score', 'reading_score', 'writing_score'], dtype='object')

# %%
df['average_scores'] = round(df[df_num_cols].mean(axis=1),2)
df.head()
# Out:
#    gender class_group parental_level_of_education         lunch  \
# 0    male     group A                 high school      standard
# 1  female     group D            some high school  free/reduced
# 2    male     group E                some college  free/reduced
# 3    male     group B                 high school      standard
# 4    male     group E          associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68
#
#    average_scores
# 0           65.67
# 1           51.33
# 2           56.33
# 3           74.33
# 4           73.00

# %%
df.drop(columns='col name')

# %% [markdown]
# ## Data Aggregation

# %% [markdown]
# `unique()` function

# %%
df['parental_level_of_education'].unique()
# Out:
# array(['high school', 'some high school', 'some college',
#        "associate's degree", "bachelor's degree", "master's degree"],
#       dtype=object)

# %% [markdown]
# `value_counts()` very useful quick and easy way to learn about the data

# %%
df['parental_level_of_education'].value_counts() #sorts the categories from largest to smallest occurrence
# Out:
# parental_level_of_education
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: count, dtype: int64

# %%
#reverse order
df['parental_level_of_education'].value_counts(ascending=True) #sort=False
# Out:
# parental_level_of_education
# master's degree        70
# bachelor's degree     112
# some high school      191
# high school           202
# associate's degree    203
# some college          222
# Name: count, dtype: int64

# %%
#convert counts to percentages
df['parental_level_of_education'].value_counts(normalize=True)
# Out:
# parental_level_of_education
# some college          0.222
# associate's degree    0.203
# high school           0.202
# some high school      0.191
# bachelor's degree     0.112
# master's degree       0.070
# Name: proportion, dtype: float64

# %% [markdown]
# - some college, associate's, and high school have equal distribution
# - master's degree has the lowest count
# - we have a low number of students with parents that have high level of education

# %% [markdown]
# `pip install matplotlib`

# %%
df['parental_level_of_education'].value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# What about numeric values?

# %%
df['math_score'].value_counts()
# Out:
# math_score
# 63    34
# 71    30
# 77    30
# 74    28
# 57    27
#       ..
# 26     2
# 23     1
# 29     1
# 34     1
# 25     1
# Name: count, Length: 77, dtype: int64

# %%
# using bins, I can break the distribution into ranges that are easier to read
df['math_score'].value_counts(bins=10, sort=False)
# Out:
# math_score
# (12.912, 21.7]      2
# (21.7, 30.4]        9
# (30.4, 39.1]       29
# (39.1, 47.8]       70
# (47.8, 56.5]      155
# (56.5, 65.2]      209
# (65.2, 73.9]      182
# (73.9, 82.6]      183
# (82.6, 91.3]      114
# (91.3, 100.0]      47
# Name: count, dtype: int64

# %% [markdown]
# The results above are similar to a histogram

# %%
df['math_score'].hist()
# Out:
# <Axes: >

# %% [markdown]
# - Students with lower scores (ie 20 to 40) represent a low number in the class

# %% [markdown]
# bins with `value_counts` splits the ranges evenly by 10 or any number. There's another method to have rounded cut points using `cut()` function

# %%
#bins = [0, 50, 65, 80, 90, 100]
bins = [0, 50, 65, 80, 90, np.inf]

#create a column for such bins
df['average_scores_bins'] = pd.cut(df['average_scores'], bins)
df.head()
# Out:
#    gender class_group parental_level_of_education         lunch  \
# 0    male     group A                 high school      standard
# 1  female     group D            some high school  free/reduced
# 2    male     group E                some college  free/reduced
# 3    male     group B                 high school      standard
# 4    male     group E          associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68
#
#    average_scores average_scores_bins
# 0           65.67        (65.0, 80.0]
# 1           51.33        (50.0, 65.0]
# 2           56.33        (50.0, 65.0]
# ...

# %%
df[df['average_scores']>90].head()
# Out:
#     gender class_group parental_level_of_education     lunch  \
# 44    male     group E                 high school  standard
# 64    male     group D             master's degree  standard
# 87    male     group D                some college  standard
# 93    male     group D           bachelor's degree  standard
# 96  female     group E          associate's degree  standard
#
#    test_preparation_course  math_score  reading_score  writing_score  \
# 44                    none         100             88             87
# 64               completed          83             93             97
# 87                    none          97             93             88
# 93               completed          94             87             93
# 96               completed          95            100            100
#
#     average_scores average_scores_bins
# 44           91.67         (90.0, inf]
# 64           91.00         (90.0, inf]
# 87           92.67         (90.0, inf]
# ...

# %%
df['average_scores_bins'].value_counts(sort=False)
# Out:
# average_scores_bins
# (0.0, 50.0]     127
# (50.0, 65.0]    304
# (65.0, 80.0]    365
# (80.0, 90.0]    149
# (90.0, inf]      55
# Name: count, dtype: int64

# %% [markdown]
# Aggregation for Specific Column(s)

# %%
# find the average of math score by gender
df_avg_gen = df[['gender','math_score']].groupby('gender').mean()
df_avg_gen
# Out:
#         math_score
# gender
# female   63.196687
# male     69.384913

# %% [markdown]
# Comparison to SQL:
# ```SQL
# SELECT gender, AVG(math_score)
# FROM df
# GROUP BY gender

# %%
df_avg_gen.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
#lowest reading score by class group
df[['class_group', 'reading_score']].groupby('class_group').min()
# Out:
#              reading_score
# class_group
# group A                 33
# group B                 28
# group C                 27
# group D                 36
# group E                 32

# %% [markdown]
# Using `agg()` to specify multiple aggregation functions

# %%
df[['class_group', 'reading_score']].groupby('class_group').agg(['min', 'max', 'mean'])
# Out:
#             reading_score
#                       min  max       mean
# class_group
# group A                33  100  68.556962
# group B                28   98  67.102439
# group C                27  100  66.383901
# group D                36  100  72.087786
# group E                32  100  72.526718

# %%
df[['class_group', 'reading_score']].groupby('class_group').agg(['min', 'max', 'mean']).plot(kind='barh')
# Out:
# <Axes: ylabel='class_group'>

# %% [markdown]
# ### Advanced Aggregation

# %% [markdown]
# use a custom function for aggregation

# %%
def score_range(col):
    return col.max() - col.min()

df.groupby(['class_group'])['reading_score'].agg(['min', 'max', score_range])
# Out:
#              min  max  score_range
# class_group
# group A       33  100           67
# group B       28   98           70
# group C       27  100           73
# group D       36  100           64
# group E       32  100           68

# %%
df.groupby(['class_group'])[df_num_cols].agg(['min', 'max', score_range])
# Out:
#             math_score                  reading_score                   \
#                    min  max score_range           min  max score_range
# class_group
# group A             33   94          61            33  100          67
# group B             25   99          74            28   98          70
# group C             13  100          87            27  100          73
# group D             13  100          87            36  100          64
# group E             33  100          67            32  100          68
#
#             writing_score
#                       min  max score_range
# class_group
# group A                32  100          68
# group B                23  100          77
# group C                23  100          77
# group D                37  100          63
# group E                32  100          68

# %%
df.groupby(['gender','class_group'])[df_num_cols].agg(['min', 'max', score_range])
# Out:
#                    math_score                  reading_score                   \
#                           min  max score_range           min  max score_range
# gender class_group
# female group A             33   94          61            50  100          50
#        group B             25   96          71            29   98          69
#        group C             13   94          81            29  100          71
#        group D             13  100          87            36  100          64
#        group E             33  100          67            32  100          68
# male   group A             40   91          51            33   97          64
#        group B             36   99          63            28   96          68
#        group C             29  100          71            27   99          72
#        group D             35  100          65            36   97          61
#        group E             46  100          54            38  100          62
#
# ...

# %% [markdown]
# What if we want a different agg function for each numeric value

# %%
df.groupby(['gender','class_group'])[df_num_cols].agg({'math_score':'mean',
                                                       'reading_score':'max',
                                                       'writing_score':'std'})
# Out:
#                     math_score  reading_score  writing_score
# gender class_group
# female group A       65.216216            100      14.162188
#        group B       59.631579             98      13.921554
#        group C       60.753247            100      15.685855
#        group D       65.722222            100      14.593238
#        group E       70.692308            100      16.246255
# male   group A       65.214286             97      16.277804
#        group B       67.604396             96      15.361052
#        group C       65.295858             99      14.359444
#        group D       72.551471             97      13.794016
#        group E       76.949367            100      14.834738

# %%
df.groupby(['gender','class_group'])[df_num_cols].agg(avg_math_score=('math_score', 'mean'),
                                                      max_reading_score=('reading_score', 'max'))
# Out:
#                     avg_math_score  max_reading_score
# gender class_group
# female group A           65.216216                100
#        group B           59.631579                 98
#        group C           60.753247                100
#        group D           65.722222                100
#        group E           70.692308                100
# male   group A           65.214286                 97
#        group B           67.604396                 96
#        group C           65.295858                 99
#        group D           72.551471                 97
#        group E           76.949367                100

# %% [markdown]
# Using `pivot_table()`

# %%
df.pivot_table(index='class_group', columns='gender', values=['reading_score', 'math_score'], aggfunc=['mean', 'max']).round(2)
# Out:
#                   mean                                    max       \
#             math_score        reading_score        math_score
# gender          female   male        female   male     female male
# class_group
# group A          65.22  65.21         74.43  63.38         94   91
# group B          59.63  67.60         68.46  65.40         96   99
# group C          60.75  65.30         69.94  63.14         94  100
# group D          65.72  72.55         75.16  69.24        100  100
# group E          70.69  76.95         75.42  70.62        100  100
#
#
#             reading_score
# gender             female male
# class_group
# group A               100   97
# group B                98   96
# group C               100   99
# group D               100   97
# group E               100  100

# %% [markdown]
# For all class groups, female groups have higher average of reading score compared to male groups.

# %%
# export output into json
df.pivot_table(index='class_group', columns='gender', values='reading_score', aggfunc=['mean', 'max']).to_json('my_json_output.json')

# %% [markdown]
# Using `crosstab()`

# %%
pd.crosstab(index=df['class_group'], columns=df['parental_level_of_education'], normalize=True)
# Out:
# parental_level_of_education  associate's degree  bachelor's degree  \
# class_group
# group A                                   0.011              0.014
# group B                                   0.040              0.020
# group C                                   0.075              0.035
# group D                                   0.050              0.029
# group E                                   0.027              0.014
#
# parental_level_of_education  high school  master's degree  some college  \
# class_group
# group A                            0.015            0.008         0.020
# group B                            0.039            0.019         0.049
# group C                            0.058            0.020         0.069
# group D                            0.059            0.016         0.057
# group E                            0.031            0.007         0.027
#
# parental_level_of_education  some high school
# class_group
# ...

# %%
pd.crosstab(index=df['class_group'], columns=df['parental_level_of_education'])
# Out:
# parental_level_of_education  associate's degree  bachelor's degree  \
# class_group
# group A                                      11                 14
# group B                                      40                 20
# group C                                      75                 35
# group D                                      50                 29
# group E                                      27                 14
#
# parental_level_of_education  high school  master's degree  some college  \
# class_group
# group A                               15                8            20
# group B                               39               19            49
# group C                               58               20            69
# group D                               59               16            57
# group E                               31                7            27
#
# parental_level_of_education  some high school
# class_group
# ...

# %%
pd.crosstab(index=df['class_group'], columns=df['parental_level_of_education'], normalize='index')
# Out:
# parental_level_of_education  associate's degree  bachelor's degree  \
# class_group
# group A                                0.139241           0.177215
# group B                                0.195122           0.097561
# group C                                0.232198           0.108359
# group D                                0.190840           0.110687
# group E                                0.206107           0.106870
#
# parental_level_of_education  high school  master's degree  some college  \
# class_group
# group A                         0.189873         0.101266      0.253165
# group B                         0.190244         0.092683      0.239024
# group C                         0.179567         0.061920      0.213622
# group D                         0.225191         0.061069      0.217557
# group E                         0.236641         0.053435      0.206107
#
# parental_level_of_education  some high school
# class_group
# ...

# %% [markdown]
# Group A has the highest distribution of students with parents with higher education.

# %%
for cat in df['parental_level_of_education'].unique():
    print(cat,'max value:',pd.crosstab(index=df['class_group'], columns=df['parental_level_of_education'], normalize='index')[cat].max())
# Out:
# high school max value: 0.2366412213740458
# some high school max value: 0.2043343653250774
# some college max value: 0.25316455696202533
# associate's degree max value: 0.23219814241486067
# bachelor's degree max value: 0.17721518987341772
# master's degree max value: 0.10126582278481013

# %% [markdown]
# Relationship Analysis Using Scatterplots

# %%
df.plot.scatter(x='reading_score',y='writing_score')
# Out:
# <Axes: xlabel='reading_score', ylabel='writing_score'>

# %% [markdown]
# - Reading and Writing scores have a strong relationship
# - If a student gets a high score in reading, there's a high chance they'll get a high score in writing
# - Strong positive correlation

# %%
df[['reading_score', 'writing_score']].corr()
# Out:
#                reading_score  writing_score
# reading_score       1.000000       0.954274
# writing_score       0.954274       1.000000

# %%
#deactivate the index and use | instead of , for separation
df.to_csv('schoo_grades_final.csv', sep='|', index=False)
