# %% [markdown]
# # Hyperparameter Tuning and Cross-Validation Using `GridSearchCV`

# %% [markdown]
# - **Hyperparameters** parameters or knobs in the ML algo that are set by the user before training begins. It dictates the complexity and variation of the ML algorithm.
# - **Hyperparameter Tuning** is the process of finding the best **hyperparameters** settings for a Machine Learning model. Basically, it's done by trying different values and permutations with model evaluation to get the best performance.
# - **Cross-Validation**
#     - Very important concept in ML. It involves partitioning the dataset into multiple subsets (called **folds**) then training and evaluation the model accuracy multiple times - each time using a different fold for train dataset.
#     - It helps provide more reliable estimate of the model's performance  by reducing the chance of focusing on sub group of the data in a single train-test-split operation.

# %% [markdown]
# ![cv](https://www.mathworks.com/discovery/cross-validation/_jcr_content/mainParsys/image.adapt.full.medium.jpg/1718274806179.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#sklearn libraries
from sklearn.datasets import make_classification #to generate synthetic data
from sklearn.model_selection import train_test_split, GridSearchCV #to split the data into train and test and use GridSearchCV
from sklearn.tree import DecisionTreeClassifier #the ML algo 
from sklearn.metrics import accuracy_score #evaluation

# %%
# generate the data

X, y = make_classification(n_samples=9000,
                           n_features=18,
                           n_informative=4,
                           n_redundant=12,
                           random_state=2)

# %%
# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
#dtc_model = DecisionTreeClassifier(max_depth=i)
#dtc_model.fit(X_train, y_train)

# %% [markdown]
# - There's a dedicated function for performing cross-validation only
# - However, it's recommended to perform cross-validation with hyperparameter tuning all in one functionality called `GridSearchCV`
# - Possible Hyperparameters for our model:
# ```python
# class sklearn.tree.DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0, monotonic_cst=None)
# ```

# %% [markdown]
# 1. Define the Hyperparameter Grid as a dicationary

# %%
param_grid = {
                'criterion': ['gini', 'entropy'],
                'max_depth': [2,4,6,10,20],
                'min_samples_split' : [ 2,5,10,15,20],
                'random_state':[10]
            }

# %% [markdown]
# 2. Define the number of Cross-Validation Folds and the evaluation metric

# %%
cv_folds = 5
evaluation_metric = 'accuracy'

# %% [markdown]
# 3. Deploy `GridSearchCV` with `DecisionTreeClassifier`

# %%
gs_dtc = GridSearchCV(DecisionTreeClassifier(),#call the model function without hyperparameters
                      param_grid,
                      scoring=evaluation_metric, 
                      cv=cv_folds
                      )

# %%
gs_dtc.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 10, 20],
#                          'min_samples_split': [2, 5, 10, 15, 20],
#                          'random_state': [10]},
#              scoring='accuracy')

# %% [markdown]
# How many trials/iterations did `GridSearchCV do? 2 x 5 x 5 (hyperparameters)  x 5 (cv)

# %% [markdown]
# We can ask `GridSearchCV` to provide the best hyperparameters

# %%
gs_dtc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_split': 20,
#  'random_state': 10}

# %%
gs_dtc.best_score_
# Out:
# 0.8873333333333333

# %% [markdown]
# The hyperparameters above give 88.7% accuracy score

# %% [markdown]
# We can view the results of all the iterations

# %%
pd.DataFrame(gs_dtc.cv_results_).head(10)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.023123      0.003084         0.000584        0.000236
# 1       0.020866      0.000169         0.000551        0.000207
# 2       0.020834      0.000619         0.000483        0.000223
# 3       0.020625      0.000530         0.000694        0.000290
# 4       0.021235      0.000378         0.000543        0.000262
# 5       0.039322      0.000421         0.000538        0.000052
# 6       0.044461      0.011339         0.000536        0.000193
# 7       0.038548      0.000293         0.000594        0.000361
# 8       0.038471      0.000392         0.000722        0.000286
# 9       0.037399      0.000557         0.000691        0.000345
#
#   param_criterion param_max_depth param_min_samples_split param_random_state  \
# 0            gini               2                       2                 10
# 1            gini               2                       5                 10
# 2            gini               2                      10                 10
# 3            gini               2                      15                 10
# 4            gini               2                      20                 10
# 5            gini               4                       2                 10
# 6            gini               4                       5                 10
# 7            gini               4                      10                 10
# 8            gini               4                      15                 10
# 9            gini               4                      20                 10
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.704444
# 1  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.704444
# 2  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.704444
# 3  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.704444
# 4  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.704444
# 5  {'criterion': 'gini', 'max_depth': 4, 'min_sam...           0.830000
# 6  {'criterion': 'gini', 'max_depth': 4, 'min_sam...           0.830000
# 7  {'criterion': 'gini', 'max_depth': 4, 'min_sam...           0.830000
# 8  {'criterion': 'gini', 'max_depth': 4, 'min_sam...           0.830000
# 9  {'criterion': 'gini', 'max_depth': 4, 'min_sam...           0.830000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.697222           0.707222           0.683333           0.713333
# 1           0.697222           0.707222           0.683333           0.713333
# 2           0.697222           0.707222           0.683333           0.713333
# 3           0.697222           0.707222           0.683333           0.713333
# 4           0.697222           0.707222           0.683333           0.713333
# 5           0.827778           0.831111           0.817778           0.802222
# 6           0.827778           0.831111           0.817778           0.802222
# 7           0.827778           0.831111           0.817778           0.802222
# 8           0.827778           0.831111           0.817778           0.802222
# 9           0.827778           0.831111           0.817778           0.802222
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.701111        0.010286               46
# 1         0.701111        0.010286               46
# 2         0.701111        0.010286               46
# 3         0.701111        0.010286               46
# 4         0.701111        0.010286               46
# 5         0.821778        0.010855               31
# 6         0.821778        0.010855               31
# 7         0.821778        0.010855               31
# 8         0.821778        0.010855               31
# 9         0.821778        0.010855               31

# %%
from sklearn.tree import export_text

tree_view = export_text(gs_dtc.best_estimator_)
print(tree_view)
# Out:
# |--- feature_9 <= 0.69
# |   |--- feature_16 <= -0.72
# |   |   |--- feature_15 <= 0.65
# |   |   |   |--- feature_9 <= -0.66
# |   |   |   |   |--- feature_9 <= -0.91
# |   |   |   |   |   |--- feature_16 <= -1.48
# |   |   |   |   |   |   |--- feature_12 <= -0.03
# |   |   |   |   |   |   |   |--- feature_4 <= -1.51
# |   |   |   |   |   |   |   |   |--- feature_5 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_5 >  0.11
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -2.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -2.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  -1.51
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_12 >  -0.03
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_16 >  -1.48
# |   |   |   |   |   |   |--- feature_6 <= 1.66
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  1.66
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_9 >  -0.91
# |   |   |   |   |   |--- feature_15 <= 0.01
# |   |   |   |   |   |   |--- feature_10 <= -0.85
# |   |   |   |   |   |   |   |--- feature_13 <= 0.49
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_13 >  0.49
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_10 >  -0.85
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_15 >  0.01
# |   |   |   |   |   |   |--- feature_1 <= -0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  -0.92
# |   |   |   |   |   |   |   |--- feature_9 <= -0.90
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  -0.90
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.22
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.22
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_9 >  -0.66
# |   |   |   |   |--- feature_16 <= -1.10
# |   |   |   |   |   |--- feature_16 <= -1.63
# |   |   |   |   |   |   |--- feature_12 <= -2.21
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_12 >  -2.21
# |   |   |   |   |   |   |   |--- feature_0 <= 3.00
# |   |   |   |   |   |   |   |   |--- feature_15 <= -0.54
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_15 >  -0.54
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  3.00
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_17 >  1.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_16 >  -1.63
# |   |   |   |   |   |   |--- feature_15 <= 0.24
# |   |   |   |   |   |   |   |--- feature_9 <= -0.59
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  -0.59
# |   |   |   |   |   |   |   |   |--- feature_8 <= 1.74
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  1.74
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_15 >  0.24
# |   |   |   |   |   |   |   |--- feature_8 <= 0.48
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  0.48
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_16 >  -1.10
# |   |   |   |   |   |--- feature_15 <= -0.29
# |   |   |   |   |   |   |--- feature_5 <= 1.12
# |   |   |   |   |   |   |   |--- feature_15 <= -0.46
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.79
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= -0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  -0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.79
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_15 >  -0.46
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  1.12
# |   |   |   |   |   |   |   |--- feature_13 <= -0.83
# |   |   |   |   |   |   |   |   |--- feature_11 <= -1.29
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= -1.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  -1.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_11 >  -1.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_13 >  -0.83
# |   |   |   |   |   |   |   |   |--- feature_17 <= -0.71
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_17 >  -0.71
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= -0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  -0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  -0.29
# |   |   |   |   |   |   |--- feature_0 <= 1.15
# |   |   |   |   |   |   |   |--- feature_9 <= -0.63
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  -0.63
# |   |   |   |   |   |   |   |   |--- feature_12 <= -0.47
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_12 >  -0.47
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  1.15
# |   |   |   |   |   |   |   |--- feature_7 <= 1.17
# |   |   |   |   |   |   |   |   |--- feature_3 <= -1.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  -1.85
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= -0.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  -0.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  1.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_15 >  0.65
# |   |   |   |--- feature_8 <= 0.13
# |   |   |   |   |--- feature_16 <= -2.01
# |   |   |   |   |   |--- feature_16 <= -2.36
# |   |   |   |   |   |   |--- feature_8 <= 0.11
# |   |   |   |   |   |   |   |--- feature_1 <= -1.99
# |   |   |   |   |   |   |   |   |--- feature_16 <= -2.40
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_16 >  -2.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  -1.99
# |   |   |   |   |   |   |   |   |--- feature_1 <= -1.97
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  -1.97
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -1.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -1.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.11
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_16 >  -2.36
# |   |   |   |   |   |   |--- feature_9 <= -0.76
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_9 >  -0.76
# |   |   |   |   |   |   |   |--- feature_11 <= 0.59
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_11 >  0.59
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_16 >  -2.01
# |   |   |   |   |   |--- feature_2 <= 1.71
# |   |   |   |   |   |   |--- feature_2 <= 1.17
# |   |   |   |   |   |   |   |--- feature_0 <= 1.28
# |   |   |   |   |   |   |   |   |--- feature_4 <= -0.95
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  -0.95
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  1.28
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  1.17
# |   |   |   |   |   |   |   |--- feature_15 <= 1.11
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_15 >  1.11
# |   |   |   |   |   |   |   |   |--- feature_16 <= -1.38
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_16 >  -1.38
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  1.71
# |   |   |   |   |   |   |--- feature_15 <= 0.86
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_15 >  0.86
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_8 >  0.13
# |   |   |   |   |--- feature_12 <= -0.97
# |   |   |   |   |   |--- feature_15 <= 0.86
# |   |   |   |   |   |   |--- feature_1 <= -0.22
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  -0.22
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_15 >  0.86
# |   |   |   |   |   |   |--- feature_0 <= 1.19
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  1.19
# |   |   |   |   |   |   |   |--- feature_8 <= 1.01
# |   |   |   |   |   |   |   |   |--- feature_8 <= 1.01
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= -1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  -1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  1.01
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  1.01
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_12 >  -0.97
# |   |   |   |   |   |--- feature_4 <= -1.26
# |   |   |   |   |   |   |--- feature_0 <= 1.17
# |   |   |   |   |   |   |   |--- feature_15 <= 0.72
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_15 >  0.72
# |   |   |   |   |   |   |   |   |--- feature_13 <= -2.31
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_13 >  -2.31
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  1.17
# |   |   |   |   |   |   |   |--- feature_9 <= -0.41
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1.21
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= -1.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  -1.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_11 >  1.21
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  -0.41
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_4 >  -1.26
# |   |   |   |   |   |   |--- feature_10 <= 0.76
# |   |   |   |   |   |   |   |--- feature_17 <= 0.44
# |   |   |   |   |   |   |   |   |--- feature_10 <= -0.65
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_10 >  -0.65
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_17 >  0.44
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.85
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.85
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_10 >  0.76
# |   |   |   |   |   |   |   |--- class: 1
# |   |--- feature_16 >  -0.72
# |   |   |--- feature_7 <= 0.60
# |   |   |   |--- feature_15 <= -1.26
# |   |   |   |   |--- feature_8 <= 1.42
# |   |   |   |   |   |--- feature_3 <= -1.52
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  -1.52
# |   |   |   |   |   |   |--- feature_3 <= 1.36
# |   |   |   |   |   |   |   |--- feature_16 <= -0.07
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_16 >  -0.07
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.19
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  1.36
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  1.42
# |   |   |   |   |   |--- feature_15 <= -2.18
# |   |   |   |   |   |   |--- feature_12 <= -3.53
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_12 >  -3.53
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  -2.18
# |   |   |   |   |   |   |--- feature_8 <= 1.93
# |   |   |   |   |   |   |   |--- feature_15 <= -1.66
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_15 >  -1.66
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.22
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.22
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  1.93
# |   |   |   |   |   |   |   |--- feature_0 <= 2.77
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.14
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  2.77
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_15 >  -1.26
# |   |   |   |   |--- feature_15 <= -1.05
# |   |   |   |   |   |--- feature_1 <= 0.43
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.43
# |   |   |   |   |   |   |--- feature_3 <= -0.61
# |   |   |   |   |   |   |   |--- feature_2 <= -0.32
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1.74
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= -1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  -1.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_6 >  1.74
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  -0.32
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  -0.61
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_15 >  -1.05
# |   |   |   |   |   |--- feature_14 <= -2.68
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_14 >  -2.68
# |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |--- feature_2 <= -0.68
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  -0.68
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |--- feature_17 <= 1.11
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.04
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.04
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_17 >  1.11
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1.12
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_17 >  1.12
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_7 >  0.60
# |   |   |   |--- feature_3 <= -0.71
# |   |   |   |   |--- feature_8 <= 2.33
# |   |   |   |   |   |--- feature_15 <= -1.57
# |   |   |   |   |   |   |--- feature_3 <= -1.60
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  -1.60
# |   |   |   |   |   |   |   |--- feature_15 <= -1.67
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_15 >  -1.67
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  -1.57
# |   |   |   |   |   |   |--- feature_15 <= 0.30
# |   |   |   |   |   |   |   |--- feature_1 <= 2.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.95
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= -2.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  -2.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.95
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= -3.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  -3.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  2.10
# |   |   |   |   |   |   |   |   |--- feature_15 <= -0.74
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= -1.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  -1.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_15 >  -0.74
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_15 >  0.30
# |   |   |   |   |   |   |   |--- feature_14 <= -0.72
# |   |   |   |   |   |   |   |   |--- feature_6 <= -2.26
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_6 >  -2.26
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_14 >  -0.72
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  2.33
# |   |   |   |   |   |--- feature_15 <= -2.83
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  -2.83
# |   |   |   |   |   |   |--- feature_8 <= 2.75
# |   |   |   |   |   |   |   |--- feature_15 <= -2.01
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_15 >  -2.01
# |   |   |   |   |   |   |   |   |--- feature_13 <= 1.59
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= -2.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  -2.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_13 >  1.59
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  2.75
# |   |   |   |   |   |   |   |--- feature_16 <= -0.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_16 >  -0.21
# |   |   |   |   |   |   |   |   |--- feature_15 <= -2.54
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= -4.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  -4.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_15 >  -2.54
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  -0.71
# |   |   |   |   |--- feature_15 <= -0.85
# |   |   |   |   |   |--- feature_14 <= -0.94
# |   |   |   |   |   |   |--- feature_8 <= 3.20
# |   |   |   |   |   |   |   |--- feature_15 <= -1.18
# |   |   |   |   |   |   |   |   |--- feature_9 <= -1.31
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_9 >  -1.31
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 2.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  2.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_15 >  -1.18
# |   |   |   |   |   |   |   |   |--- feature_12 <= -1.87
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_12 >  -1.87
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  3.20
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_14 >  -0.94
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_15 >  -0.85
# |   |   |   |   |   |--- feature_15 <= 1.05
# |   |   |   |   |   |   |--- feature_8 <= 0.63
# |   |   |   |   |   |   |   |--- feature_0 <= 0.56
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.88
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  0.56
# |   |   |   |   |   |   |   |   |--- feature_13 <= 0.25
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_13 >  0.25
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.63
# |   |   |   |   |   |   |   |--- feature_3 <= 0.20
# |   |   |   |   |   |   |   |   |--- feature_4 <= -0.75
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  -0.75
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1.41
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  1.41
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  0.20
# |   |   |   |   |   |   |   |   |--- feature_4 <= -1.48
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= -1.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  -1.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  -1.48
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  1.05
# |   |   |   |   |   |   |--- feature_10 <= -0.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_10 >  -0.09
# |   |   |   |   |   |   |   |--- feature_17 <= 0.83
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_17 >  0.83
# |   |   |   |   |   |   |   |   |--- class: 1
# |--- feature_9 >  0.69
# |   |--- feature_16 <= 0.66
# |   |   |--- feature_2 <= -1.27
# |   |   |   |--- feature_15 <= 0.70
# |   |   |   |   |--- feature_12 <= -4.59
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_12 >  -4.59
# |   |   |   |   |   |--- feature_7 <= -0.30
# |   |   |   |   |   |   |--- feature_15 <= -0.21
# |   |   |   |   |   |   |   |--- feature_5 <= 2.64
# |   |   |   |   |   |   |   |   |--- feature_13 <= 2.18
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= -1.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  -1.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_13 >  2.18
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_5 >  2.64
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_15 >  -0.21
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_7 >  -0.30
# |   |   |   |   |   |   |--- feature_15 <= -2.26
# |   |   |   |   |   |   |   |--- feature_3 <= -2.78
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1.19
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_9 >  1.19
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= -2.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  -2.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  -2.78
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_15 >  -2.26
# |   |   |   |   |   |   |   |--- feature_16 <= 0.27
# |   |   |   |   |   |   |   |   |--- feature_13 <= 0.93
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_13 >  0.93
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_16 >  0.27
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_15 >  0.70
# |   |   |   |   |--- class: 0
# |   |   |--- feature_2 >  -1.27
# |   |   |   |--- feature_16 <= -0.09
# |   |   |   |   |--- feature_16 <= -0.95
# |   |   |   |   |   |--- feature_15 <= 1.06
# |   |   |   |   |   |   |--- feature_5 <= 1.66
# |   |   |   |   |   |   |   |--- feature_2 <= -0.74
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  -0.74
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  1.66
# |   |   |   |   |   |   |   |--- feature_16 <= -2.31
# |   |   |   |   |   |   |   |   |--- feature_8 <= 1.29
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  1.29
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_16 >  -2.31
# |   |   |   |   |   |   |   |   |--- feature_16 <= -2.31
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_16 >  -2.31
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_15 >  1.06
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_16 >  -0.95
# |   |   |   |   |   |--- feature_15 <= -1.09
# |   |   |   |   |   |   |--- feature_3 <= -1.66
# |   |   |   |   |   |   |   |--- feature_0 <= 1.96
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  1.96
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.93
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= -0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  -0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.93
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  -1.66
# |   |   |   |   |   |   |   |--- feature_2 <= -0.80
# |   |   |   |   |   |   |   |   |--- feature_15 <= -1.14
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= -1.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  -1.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_15 >  -1.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  -0.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_15 >  -1.09
# |   |   |   |   |   |   |--- feature_0 <= 1.87
# |   |   |   |   |   |   |   |--- feature_9 <= 0.69
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  0.69
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  1.87
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_16 >  -0.09
# |   |   |   |   |--- feature_15 <= -1.80
# |   |   |   |   |   |--- feature_3 <= -2.62
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  -2.62
# |   |   |   |   |   |   |--- feature_6 <= 1.39
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_6 >  1.39
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_15 >  -1.80
# |   |   |   |   |   |--- feature_5 <= 1.52
# |   |   |   |   |   |   |--- feature_6 <= -2.04
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_6 >  -2.04
# |   |   |   |   |   |   |   |--- feature_9 <= 0.70
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  0.70
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_5 >  1.52
# |   |   |   |   |   |   |--- class: 1
# |   |--- feature_16 >  0.66
# |   |   |--- feature_15 <= -2.69
# |   |   |   |--- feature_12 <= -4.66
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_12 >  -4.66
# |   |   |   |   |--- feature_8 <= 3.49
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  3.49
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_15 >  -2.69
# |   |   |   |--- feature_15 <= -2.20
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_15 >  -2.20
# |   |   |   |   |--- class: 0
